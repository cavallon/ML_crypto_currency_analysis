# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import pandas as pd
import tensorflow as tf
import numpy as np

# %%
bt = pd.read_csv("Bitcoin Historical Data (2014-2024).csv")
bt
# Out:
#             Date     Price      Open      High       Low     Vol. Change %
# 0     03/24/2024  67,211.9  64,036.5  67,587.8  63,812.9   65.59K    4.96%
# 1     03/23/2024  64,037.8  63,785.6  65,972.4  63,074.9   35.11K    0.40%
# 2     03/22/2024  63,785.5  65,501.5  66,633.3  62,328.3   72.43K   -2.62%
# 3     03/21/2024  65,503.8  67,860.0  68,161.7  64,616.1   75.26K   -3.46%
# 4     03/20/2024  67,854.0  62,046.8  68,029.5  60,850.9  133.53K    9.35%
# ...          ...       ...       ...       ...       ...      ...      ...
# 3649  03/28/2014     482.6     460.5     515.0     453.8    4.11K    4.81%
# 3650  03/27/2014     460.5     562.5     567.8     460.5    3.78K  -18.13%
# 3651  03/26/2014     562.5     562.9     575.4     546.3    3.71K   -0.08%
# 3652  03/25/2014     562.9     567.6     569.7     550.4    3.87K   -0.82%
# 3653  03/24/2014     567.6     551.2     572.5     531.3    3.67K    2.98%
#
# [3654 rows x 7 columns]

# %%
bt.dtypes
# Out:
# Date        object
# Price       object
# Open        object
# High        object
# Low         object
# Vol.        object
# Change %    object
# dtype: object

# %%
#reformatting to drop k and m, change to integers

#function loop  to drop and multiply
def km_to_number(value):
    if isinstance(value, str):
        if 'K' in value:
            return float(value.replace('K', '')) * 1000
        elif 'M' in value:
            return float(value.replace('M', '')) * 1000000
        elif 'B' in value:
            return float(value.replace('B', '')) * 1000000000
    else:
        return value

bt["Vol."] = bt["Vol."].apply(km_to_number)

bt
# Out:
#             Date     Price      Open      High       Low      Vol. Change %
# 0     03/24/2024  67,211.9  64,036.5  67,587.8  63,812.9   65590.0    4.96%
# 1     03/23/2024  64,037.8  63,785.6  65,972.4  63,074.9   35110.0    0.40%
# 2     03/22/2024  63,785.5  65,501.5  66,633.3  62,328.3   72430.0   -2.62%
# 3     03/21/2024  65,503.8  67,860.0  68,161.7  64,616.1   75260.0   -3.46%
# 4     03/20/2024  67,854.0  62,046.8  68,029.5  60,850.9  133530.0    9.35%
# ...          ...       ...       ...       ...       ...       ...      ...
# 3649  03/28/2014     482.6     460.5     515.0     453.8    4110.0    4.81%
# 3650  03/27/2014     460.5     562.5     567.8     460.5    3780.0  -18.13%
# 3651  03/26/2014     562.5     562.9     575.4     546.3    3710.0   -0.08%
# 3652  03/25/2014     562.9     567.6     569.7     550.4    3870.0   -0.82%
# 3653  03/24/2014     567.6     551.2     572.5     531.3    3670.0    2.98%
#
# [3654 rows x 7 columns]

# %%
#convert to date to datetime, price/open/high/low to float, change% to float
bt["Date"] = pd.to_datetime(bt["Date"])
bt[["Price", "Open", "High", "Low"]] = bt[["Price", "Open", "High", "Low"]].applymap(lambda x: float(x.replace(',', '')))
bt['Change %'] = bt['Change %'].str.rstrip('%').astype(float)
bt
# Out:
#            Date    Price     Open     High      Low      Vol.  Change %
# 0    2024-03-24  67211.9  64036.5  67587.8  63812.9   65590.0      4.96
# 1    2024-03-23  64037.8  63785.6  65972.4  63074.9   35110.0      0.40
# 2    2024-03-22  63785.5  65501.5  66633.3  62328.3   72430.0     -2.62
# 3    2024-03-21  65503.8  67860.0  68161.7  64616.1   75260.0     -3.46
# 4    2024-03-20  67854.0  62046.8  68029.5  60850.9  133530.0      9.35
# ...         ...      ...      ...      ...      ...       ...       ...
# 3649 2014-03-28    482.6    460.5    515.0    453.8    4110.0      4.81
# 3650 2014-03-27    460.5    562.5    567.8    460.5    3780.0    -18.13
# 3651 2014-03-26    562.5    562.9    575.4    546.3    3710.0     -0.08
# 3652 2014-03-25    562.9    567.6    569.7    550.4    3870.0     -0.82
# 3653 2014-03-24    567.6    551.2    572.5    531.3    3670.0      2.98
#
# [3654 rows x 7 columns]

# %%
bt.dtypes
# Out:
# Date        datetime64[ns]
# Price              float64
# Open               float64
# High               float64
# Low                float64
# Vol.               float64
# Change %           float64
# dtype: object

# %%
bt['Date'] = bt['Date'].astype('int64')
bt['Date'] = bt['Date'].astype(float)

# %%
#adding a classification for softmax activation function
conditions = [
    (bt['Change %'] > 0),
    (bt['Change %'] < 0),
    (bt['Change %'] == 0)
]
values = [1, 0, 2]

bt['Inertia'] = np.where(conditions[0], values[0],
                np.where(conditions[1], values[1], values[2]))
bt
# Out:
#               Date    Price     Open     High      Low      Vol.  Change %  \
# 0     1.711238e+18  67211.9  64036.5  67587.8  63812.9   65590.0      4.96
# 1     1.711152e+18  64037.8  63785.6  65972.4  63074.9   35110.0      0.40
# 2     1.711066e+18  63785.5  65501.5  66633.3  62328.3   72430.0     -2.62
# 3     1.710979e+18  65503.8  67860.0  68161.7  64616.1   75260.0     -3.46
# 4     1.710893e+18  67854.0  62046.8  68029.5  60850.9  133530.0      9.35
# ...            ...      ...      ...      ...      ...       ...       ...
# 3649  1.395965e+18    482.6    460.5    515.0    453.8    4110.0      4.81
# 3650  1.395878e+18    460.5    562.5    567.8    460.5    3780.0    -18.13
# 3651  1.395792e+18    562.5    562.9    575.4    546.3    3710.0     -0.08
# 3652  1.395706e+18    562.9    567.6    569.7    550.4    3870.0     -0.82
# 3653  1.395619e+18    567.6    551.2    572.5    531.3    3670.0      2.98
#
#       Inertia
# 0           1
# 1           1
# 2           0
# 3           0
# 4           1
# ...       ...
# 3649        1
# 3650        0
# 3651        0
# 3652        0
# 3653        1
#
# [3654 rows x 8 columns]

# %%
bit = bt.copy()
bit.drop(columns=["Date"])
# Out:
#         Price     Open     High      Low      Vol.  Change %  Inertia
# 0     67211.9  64036.5  67587.8  63812.9   65590.0      4.96        1
# 1     64037.8  63785.6  65972.4  63074.9   35110.0      0.40        1
# 2     63785.5  65501.5  66633.3  62328.3   72430.0     -2.62        0
# 3     65503.8  67860.0  68161.7  64616.1   75260.0     -3.46        0
# 4     67854.0  62046.8  68029.5  60850.9  133530.0      9.35        1
# ...       ...      ...      ...      ...       ...       ...      ...
# 3649    482.6    460.5    515.0    453.8    4110.0      4.81        1
# 3650    460.5    562.5    567.8    460.5    3780.0    -18.13        0
# 3651    562.5    562.9    575.4    546.3    3710.0     -0.08        0
# 3652    562.9    567.6    569.7    550.4    3870.0     -0.82        0
# 3653    567.6    551.2    572.5    531.3    3670.0      2.98        1
#
# [3654 rows x 7 columns]

# %%
y = bit["Inertia"].values
X = bit.drop(columns="Inertia").values

X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=1)

scaler = StandardScaler()

X_scaler = scaler.fit(X_train)

X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %%
# Define the model - deep neural net, i.e., the number of input features and hidden nodes for each layer.
number_input_features = len(X_train[0])
hidden_nodes_layer1 =  80
hidden_nodes_layer2 = 30
num_classes = 3

nn = tf.keras.models.Sequential()

# First hidden layer
nn.add(
    tf.keras.layers.Dense(units=hidden_nodes_layer1, input_dim=number_input_features, activation="relu")
)

# Second hidden layer
nn.add(tf.keras.layers.Dense(units=hidden_nodes_layer2, activation="relu"))

# Output layer
nn.add(tf.keras.layers.Dense(units=num_classes, activation="softmax"))
# Out:
# c:\Users\lucas\anaconda3\envs\dev\lib\site-packages\keras\src\layers\core\dense.py:88: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
#Compile
nn.compile(loss="sparse_categorical_crossentropy", optimizer="adam", metrics=["accuracy"])

#Fit
nn.fit(X_train_scaled, y_train, epochs=50, verbose=1)
# Out:
# Epoch 1/50
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.6426 - loss: 0.8847
# Epoch 2/50
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9417 - loss: 0.3116
# Epoch 3/50
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9726 - loss: 0.1570
# Epoch 4/50
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9801 - loss: 0.1145
# Epoch 5/50
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9806 - loss: 0.0958
# Epoch 6/50
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9863 - loss: 0.0678
# Epoch 7/50
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9911 - loss: 0.0638
# Epoch 8/50
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9859 - loss: 0.0621
# Epoch 9/50
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9925 - loss: 0.0427
# Epoch 10/50
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9936 - loss: 0.0366
# Epoch 11/50
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9932 - loss: 0.0391
# Epoch 12/50
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9912 - loss: 0.0352
# Epoch 13/50
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9946 - loss: 0.0313
# Epoch 14/50
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9933 - loss: 0.0328
# Epoch 15/50
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9952 - loss: 0.0244
# Epoch 16/50
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9953 - loss: 0.0278
# Epoch 17/50
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9927 - loss: 0.0271
# Epoch 18/50
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9949 - loss: 0.0231
# Epoch 19/50
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9955 - loss: 0.0200
# Epoch 20/50
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9951 - loss: 0.0253
# Epoch 21/50
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9926 - loss: 0.0270
# Epoch 22/50
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9931 - loss: 0.0272
# Epoch 23/50
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9945 - loss: 0.0246
# Epoch 24/50
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9937 - loss: 0.0249
# Epoch 25/50
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9935 - loss: 0.0239
# Epoch 26/50
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9968 - loss: 0.0163
# Epoch 27/50
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9967 - loss: 0.0151
# Epoch 28/50
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9949 - loss: 0.0178
# Epoch 29/50
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9930 - loss: 0.0239
# Epoch 30/50
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9967 - loss: 0.0177
# Epoch 31/50
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9929 - loss: 0.0226
# Epoch 32/50
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9943 - loss: 0.0203
# Epoch 33/50
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9971 - loss: 0.0119
# Epoch 34/50
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9976 - loss: 0.0115
# Epoch 35/50
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9958 - loss: 0.0132
# Epoch 36/50
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9949 - loss: 0.0173
# Epoch 37/50
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9956 - loss: 0.0162
# Epoch 38/50
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9962 - loss: 0.0138
# Epoch 39/50
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9963 - loss: 0.0155
# Epoch 40/50
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9956 - loss: 0.0136
# Epoch 41/50
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9961 - loss: 0.0145
# Epoch 42/50
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9942 - loss: 0.0163
# Epoch 43/50
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9962 - loss: 0.0125
# Epoch 44/50
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9966 - loss: 0.0137
# Epoch 45/50
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9945 - loss: 0.0150
# Epoch 46/50
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9968 - loss: 0.0140
# Epoch 47/50
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9954 - loss: 0.0126
# Epoch 48/50
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9957 - loss: 0.0129
# Epoch 49/50
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9952 - loss: 0.0158
# Epoch 50/50
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9960 - loss: 0.0126

# %%
model_loss, model_accuracy = nn.evaluate(X_test_scaled, y_test, verbose=2)
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# 29/29 - 0s - 11ms/step - accuracy: 0.9891 - loss: 0.0278
# Loss: 0.02776368334889412, Accuracy: 0.9890590906143188
