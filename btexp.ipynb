# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import pandas as pd
import tensorflow as tf
import numpy as np

# %%
bt = pd.read_csv("Bitcoin Historical Data.csv")
bt
# Out:
#             Date     Price      Open      High       Low     Vol. Change %
# 0     03/24/2024  67,211.9  64,036.5  67,587.8  63,812.9   65.59K    4.96%
# 1     03/23/2024  64,037.8  63,785.6  65,972.4  63,074.9   35.11K    0.40%
# 2     03/22/2024  63,785.5  65,501.5  66,633.3  62,328.3   72.43K   -2.62%
# 3     03/21/2024  65,503.8  67,860.0  68,161.7  64,616.1   75.26K   -3.46%
# 4     03/20/2024  67,854.0  62,046.8  68,029.5  60,850.9  133.53K    9.35%
# ...          ...       ...       ...       ...       ...      ...      ...
# 4994  07/22/2010       0.1       0.1       0.1       0.1    2.16K    0.00%
# 4995  07/21/2010       0.1       0.1       0.1       0.1    0.58K    0.00%
# 4996  07/20/2010       0.1       0.1       0.1       0.1    0.26K    0.00%
# 4997  07/19/2010       0.1       0.1       0.1       0.1    0.57K    0.00%
# 4998  07/18/2010       0.1       0.0       0.1       0.1    0.08K    0.00%
#
# [4999 rows x 7 columns]

# %%
bt.dtypes
# Out:
# Date        object
# Price       object
# Open        object
# High        object
# Low         object
# Vol.        object
# Change %    object
# dtype: object

# %%
#reformatting to drop k and m, change to integers

#function loop  to drop and multiply
def km_to_number(value):
    if isinstance(value, str):
        if 'K' in value:
            return float(value.replace('K', '')) * 1000
        elif 'M' in value:
            return float(value.replace('M', '')) * 1000000
        elif 'B' in value:
            return float(value.replace('B', '')) * 1000000000
    else:
        return value

bt["Vol."] = bt["Vol."].apply(km_to_number)

bt
# Out:
#             Date     Price      Open      High       Low      Vol. Change %
# 0     03/24/2024  67,211.9  64,036.5  67,587.8  63,812.9   65590.0    4.96%
# 1     03/23/2024  64,037.8  63,785.6  65,972.4  63,074.9   35110.0    0.40%
# 2     03/22/2024  63,785.5  65,501.5  66,633.3  62,328.3   72430.0   -2.62%
# 3     03/21/2024  65,503.8  67,860.0  68,161.7  64,616.1   75260.0   -3.46%
# 4     03/20/2024  67,854.0  62,046.8  68,029.5  60,850.9  133530.0    9.35%
# ...          ...       ...       ...       ...       ...       ...      ...
# 4994  07/22/2010       0.1       0.1       0.1       0.1    2160.0    0.00%
# 4995  07/21/2010       0.1       0.1       0.1       0.1     580.0    0.00%
# 4996  07/20/2010       0.1       0.1       0.1       0.1     260.0    0.00%
# 4997  07/19/2010       0.1       0.1       0.1       0.1     570.0    0.00%
# 4998  07/18/2010       0.1       0.0       0.1       0.1      80.0    0.00%
#
# [4999 rows x 7 columns]

# %%
#convert to date to datetime, price/open/high/low to float, change% to float
bt["Date"] = pd.to_datetime(bt["Date"])
bt[["Price", "Open", "High", "Low"]] = bt[["Price", "Open", "High", "Low"]].applymap(lambda x: float(x.replace(',', '')))
bt['Change %'] = bt['Change %'].str.rstrip('%').astype(float)
bt
# Out:
#            Date    Price     Open     High      Low      Vol.  Change %
# 0    2024-03-24  67211.9  64036.5  67587.8  63812.9   65590.0      4.96
# 1    2024-03-23  64037.8  63785.6  65972.4  63074.9   35110.0      0.40
# 2    2024-03-22  63785.5  65501.5  66633.3  62328.3   72430.0     -2.62
# 3    2024-03-21  65503.8  67860.0  68161.7  64616.1   75260.0     -3.46
# 4    2024-03-20  67854.0  62046.8  68029.5  60850.9  133530.0      9.35
# ...         ...      ...      ...      ...      ...       ...       ...
# 4994 2010-07-22      0.1      0.1      0.1      0.1    2160.0      0.00
# 4995 2010-07-21      0.1      0.1      0.1      0.1     580.0      0.00
# 4996 2010-07-20      0.1      0.1      0.1      0.1     260.0      0.00
# 4997 2010-07-19      0.1      0.1      0.1      0.1     570.0      0.00
# 4998 2010-07-18      0.1      0.0      0.1      0.1      80.0      0.00
#
# [4999 rows x 7 columns]

# %%
bt.dtypes
# Out:
# Date        datetime64[ns]
# Price              float64
# Open               float64
# High               float64
# Low                float64
# Vol.               float64
# Change %           float64
# dtype: object

# %%
bt['Date'] = bt['Date'].astype('int64')
bt['Date'] = bt['Date'].astype(float)

# %%
#adding a classification for softmax activation function
conditions = [
    (bt['Change %'] > 0),
    (bt['Change %'] < 0),
    (bt['Change %'] == 0)
]
values = [1, 0, 2]

bt['Inertia'] = np.where(conditions[0], values[0],
                np.where(conditions[1], values[1], values[2]))
bt
# Out:
#               Date    Price     Open     High      Low      Vol.  Change %  \
# 0     1.711238e+18  67211.9  64036.5  67587.8  63812.9   65590.0      4.96
# 1     1.711152e+18  64037.8  63785.6  65972.4  63074.9   35110.0      0.40
# 2     1.711066e+18  63785.5  65501.5  66633.3  62328.3   72430.0     -2.62
# 3     1.710979e+18  65503.8  67860.0  68161.7  64616.1   75260.0     -3.46
# 4     1.710893e+18  67854.0  62046.8  68029.5  60850.9  133530.0      9.35
# ...            ...      ...      ...      ...      ...       ...       ...
# 4994  1.279757e+18      0.1      0.1      0.1      0.1    2160.0      0.00
# 4995  1.279670e+18      0.1      0.1      0.1      0.1     580.0      0.00
# 4996  1.279584e+18      0.1      0.1      0.1      0.1     260.0      0.00
# 4997  1.279498e+18      0.1      0.1      0.1      0.1     570.0      0.00
# 4998  1.279411e+18      0.1      0.0      0.1      0.1      80.0      0.00
#
#       Inertia
# 0           1
# 1           1
# 2           0
# 3           0
# 4           1
# ...       ...
# 4994        2
# 4995        2
# 4996        2
# 4997        2
# 4998        2
#
# [4999 rows x 8 columns]

# %%
bit = bt.copy()

y = bit["Inertia"].values
X = bit.drop(columns="Inertia").values

X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=1)

scaler = StandardScaler()

X_scaler = scaler.fit(X_train)

X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %%
# Define the model - deep neural net, i.e., the number of input features and hidden nodes for each layer.
number_input_features = len(X_train[0])
hidden_nodes_layer1 =  80
hidden_nodes_layer2 = 30
num_classes = 3

nn = tf.keras.models.Sequential()

# First hidden layer
nn.add(
    tf.keras.layers.Dense(units=hidden_nodes_layer1, input_dim=number_input_features, activation="relu")
)

# Second hidden layer
nn.add(tf.keras.layers.Dense(units=hidden_nodes_layer2, activation="relu"))

# Output layer
nn.add(tf.keras.layers.Dense(units=num_classes, activation="softmax"))
# Out:
# c:\Users\lucas\anaconda3\envs\dev\lib\site-packages\keras\src\layers\core\dense.py:88: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
#Compile
nn.compile(loss="sparse_categorical_crossentropy", optimizer="adam", metrics=["accuracy"])

#Fit
nn.fit(X_train_scaled, y_train, epochs=50, verbose=1)
# Out:
# Epoch 1/50
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.4687 - loss: 1.0627
# Epoch 2/50
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.4972 - loss: 0.9530
# Epoch 3/50
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.4930 - loss: 0.9338
# Epoch 4/50
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.4895 - loss: 0.9251
# Epoch 5/50
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5050 - loss: 0.9186
# Epoch 6/50
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.4843 - loss: 0.9286
# Epoch 7/50
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.4870 - loss: 0.9240
# Epoch 8/50
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.4737 - loss: 0.9351
# Epoch 9/50
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.4935 - loss: 0.9178
# Epoch 10/50
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.4765 - loss: 0.9240
# Epoch 11/50
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.4938 - loss: 0.9189
# Epoch 12/50
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.4852 - loss: 0.9219
# Epoch 13/50
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.4841 - loss: 0.9313
# Epoch 14/50
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.4833 - loss: 0.9274
# Epoch 15/50
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.4834 - loss: 0.9143
# Epoch 16/50
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.4847 - loss: 0.9300
# Epoch 17/50
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.4851 - loss: 0.9324
# Epoch 18/50
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.4958 - loss: 0.9137
# Epoch 19/50
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.4990 - loss: 0.9137
# Epoch 20/50
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.4863 - loss: 0.9185
# Epoch 21/50
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.4887 - loss: 0.9266
# Epoch 22/50
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.5006 - loss: 0.9177
# Epoch 23/50
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.4846 - loss: 0.9211
# Epoch 24/50
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.4958 - loss: 0.9157
# Epoch 25/50
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.4867 - loss: 0.9291
# Epoch 26/50
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.4943 - loss: 0.9208
# Epoch 27/50
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.4809 - loss: 0.9386
# Epoch 28/50
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.4829 - loss: 0.9372
# Epoch 29/50
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.4816 - loss: 0.9262
# Epoch 30/50
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.4836 - loss: 0.9372
# Epoch 31/50
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.4998 - loss: 0.9169
# Epoch 32/50
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.5028 - loss: 0.9152
# Epoch 33/50
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.4907 - loss: 0.9214
# Epoch 34/50
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.4768 - loss: 0.9368
# Epoch 35/50
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.4839 - loss: 0.9261
# Epoch 36/50
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.4971 - loss: 0.9222
# Epoch 37/50
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.5006 - loss: 0.9126
# Epoch 38/50
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.4829 - loss: 0.9274
# Epoch 39/50
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.4835 - loss: 0.9318
# Epoch 40/50
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.4970 - loss: 0.9256
# Epoch 41/50
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.4904 - loss: 0.9134
# Epoch 42/50
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.4921 - loss: 0.9215
# Epoch 43/50
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.4935 - loss: 0.9175
# Epoch 44/50
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.4883 - loss: 0.9252
# Epoch 45/50
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.4856 - loss: 0.9172
# Epoch 46/50
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.4797 - loss: 0.9128
# Epoch 47/50
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.4875 - loss: 0.9258
# Epoch 48/50
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.4846 - loss: 0.9173
# Epoch 49/50
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.4694 - loss: 0.9296
# Epoch 50/50
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.4817 - loss: 0.9303

# %%
model_loss, model_accuracy = nn.evaluate(X_test_scaled, y_test, verbose=2)
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# 40/40 - 0s - 5ms/step - accuracy: 0.4720 - loss: 0.9252
# Loss: 0.9252223968505859, Accuracy: 0.47200000286102295
